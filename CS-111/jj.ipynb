# %%
using Pkg
Pkg.add("Plots")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# ...

# %%
1+1
# Out:
# 2

# %%
using Plots
# Out:
# ┌ Info: Recompiling stale cache file /Users/millera2/.julia/compiled/v1.2/Plots/ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1240

# %%
x = 1:12; y = rand(12); # These are the plotting data
plot(x, y)
