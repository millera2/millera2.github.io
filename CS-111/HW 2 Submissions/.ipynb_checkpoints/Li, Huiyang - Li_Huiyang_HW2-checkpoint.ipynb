# %% [markdown]
# ##CS111 HW2 Huiyang Li
#
# #2.2.7
#     2**40/2**20/8
#     1048576/8
#     131072
#
#     The hard drive can hold 131072 songs.
#
# #2.2.8
#     a)  15*3=45
#         45-2=43
#         the answer is 43
#
#     b)  15-3=12
#         12*2=24
#         the answer is 24
#
#     c)  15*3=45
#         45//2=22
#         the answer is 22 because the result of floor division round down to the nearest integer.
#
#     d)  15*3=45
#         45/2=22.5
#         the answer is 22.5
#
#     e)  15*3=45
#         45%2=1
#         the answer is 1 because the remainder of 45//2 is 1
#
#     f)  15*3=45
#         2e0=2.0
#         45/2.0=22.5
#
# #2.3.4
#     after the computer execute x=y, y assigned its value to x.
#     after the computer execute y=x, x assigned its value to y.
#     as a result, both variables x and y have same value with y.
#
#     solution:
#     a=x
#     x=y
#     y=a
#
# #Question 4
#
# employees = input('Hello boss, please enter the name of the employees:').split(',')
# workdays = input('Please enter working days:').split(',')
# worklist = []
# a = len(workdays) - 1
# while a >= 0:
#     worklist.append([])
#     a = a - 1
# dayindex = 0
# for person in employees:
#     worklist[dayindex].append(person)
#     dayindex = (dayindex + 1) % len(workdays)
# print(worklist)
